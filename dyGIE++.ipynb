# %% [markdown]
# # It is important to have the readme.md file side to side with this file

# %%
import pandas as pd
from dygie.data.dataset_readers import document
from dygie.models import shared

# %% [markdown]
# # Preprocess data

# %%
df=pd.read_csv("/Users/jdklee/Downloads/news_sorted.csv")
df.dropna(inplace=True)
df.reset_index(inplace=True, drop=True)
df
# Out:
#       company                   pub_time  \
# 0          FB  2016-01-28 21:06:10+00:00
# 1          FB  2018-02-09 07:31:44+00:00
# 2          FB  2018-02-09 11:56:59+00:00
# 3          FB  2018-02-12 13:41:16+00:00
# 4          FB  2018-02-14 21:42:43+00:00
# ...       ...                        ...
# 29562     CVX  2021-02-10 00:57:27+00:00
# 29563     CVX  2021-02-10 15:41:50+00:00
# 29564     CVX  2021-02-12 18:33:55+00:00
# 29565     CVX  2021-02-17 12:18:56+00:00
# 29566     CVX  2021-02-17 19:58:02+00:00
#
#                                                     text  \
# 0      NEW YORK, Aug 16 (Reuters) - U.S. stocks rebou...
# 1      FILE PHOTO: Facebook co-founder Eduardo Saveri...
# 2      FILE PHOTO - Balloons are seen in front of a l...
# 3      BERLIN (Reuters) - A German consumer rights gr...
# 4      Feb 14 (Reuters) - Jana Partners:\n\n* TAKE SO...
# ...                                                  ...
# 29562  (Reuters) - About 600 gallons of petroleum and...
# ...

# %%
#Puts each row in dataframe into a .txt file
def format_data(df):
    firms=df.company.unique()
    for firm in firms:
        temp=df[df.company==firm].reset_index(drop=True)
        for i in range(len(temp)):
            print(firm,i)
            txt=open("/Users/jdklee/Documents/StatisticalML/articles/{}.txt".format(firm+"_"+str(i)),"w")
            txt.write(temp.text[i])
            txt.close()


format_data(df)

#From here, refer to readme.md for instructions on terminal

# %% [markdown]
# # Labelling

# %% [markdown]
# #### Read in data from result of prediction. For instructions on generating the predictions, refer to the readme.md on repo

# %%
dataset_events = document.Dataset.from_jsonl("/Users/jdklee/Documents/StatisticalML/aceEventPredictionResults")

print(dataset_events)
# Out:
# Dataset with 4390 documents.

# %% [markdown]
# #### This is the framework we used to handlabel the data.
# #### We print the span and predicted NER tags, and add ground truth tags manually

# %%
org="ORG"
wea="WEA"
per="PER"
veh="VEH"
gpe="GPE"
loc="LOC"
fac="FAC"
#['WEA'=weapon, 'PER'=person, 'VEH'=vehicle, 
#'GPE'=geopolitical entity, 'LOC'=location, 'ORG'=organization, 'FAC'=facility]
"""GPE : geopolitical entities, e.g. everything with a governing body like cities and countries.
    Examples: "Germany", "Buenos Aires". 
    LOC : everything else that's a physical location or area, like "Kalahari Desert" or "Silicon Valley"""


for idx,doc in enumerate(dataset_events):
    if idx>=325 and idx<600:
        print("document index:",idx)
        print("\n")
        for sent_idx,sent in enumerate(doc):
            print("start sentence index:", sent_idx)
            print(sent)
            print("event model:",sent.predicted_ner)
            print("------end of sentence {}-----\n".format(sent_idx))
            
        print("--------------------------\n")

# %%
#['WEA'=weapon, 'PER'=person, 'VEH'=vehicle, 
#'GPE'=geopolitical entity, 'LOC'=location, 'ORG'=organization, 'FAC'=facility]
"""GPE : geopolitical entities, e.g. everything with a governing body like cities and countries.
    Examples: "Germany", "Buenos Aires". 
    LOC : everything else that's a physical location or area, like "Kalahari Desert" or "Silicon Valley
    "Facility": human-made artifacts in the domains of architecture and civil engineering """
dicto1=[
    (dataset_events[14][0], [[1,1,org],[4,6,org],[7,7,org],[14,15,org]]),
    (dataset_events[14][1], []),
    (dataset_events[14][2], [[0,0,org],[13,15,fac],[21,25,gpe]]),
    (dataset_events[14][3], [[0,0,org],[2,3,per],[25,28,org],[33,38,org],[49,49,org],[52,53,per],[56,59,org],
                            [61,67,org]]),
    (dataset_events[14][4], [[1,1,org],[5,5,per],[7,12,org],[13,13,org]]),
    (dataset_events[14][5], [[11,11,per],[16,19,org],[22,22,org],[23,23,org],[25,25,org],[26,26,org],[28,28,org],[29,29,org],
                            [33,36,per],[55,56,org],[65,66,org]]),
    (dataset_events[14][6], [[1,1,org],[4,5,org],[7,8,org],[10,11,org]]),
    (dataset_events[14][7], [[35,35,per]]),
    (dataset_events[14][8], [[3,7,org]]),
    (dataset_events[14][9], [[20,20,per],[24,24,org],[27,27,org]]),
    (dataset_events[14][10], [[31,31,per],[38,38,org],[42,45,per]]),
    (dataset_events[14][11], [[1,2,org]]),
    (dataset_events[14][12], [[1,1,org],[11,15,org]]),
    (dataset_events[14][13], [[10,10,org]]),
    (dataset_events[14][14], [[13,13,per]]),
    (dataset_events[14][15], [[1,1,org]]),
    (dataset_events[14][16], []),
    (dataset_events[14][17], []),
    (dataset_events[14][18], [[1,1,org]]),
    
    (dataset_events[13][0], [[3,3,org],[6,7,org],[9,10,per],[41,42,org],[47,53,per]]),
    (dataset_events[13][1], [[27,31,per]]),
    (dataset_events[13][2], [[3,5,per],[7,7,gpe]]),
    (dataset_events[13][3], [[2,3,per]]),
    
    (dataset_events[12][0], [[0,1,gpe],[6,6,org],[9,10,per],[41,42,org],[47,53,per]]),
    (dataset_events[12][1], [[29,29,per],[32,32,org]]),
    (dataset_events[12][2], [[32,32,per]]),
    (dataset_events[12][3], [[1,1,per],[23,24,org],[26,26,per],[33,33,org]]),
    (dataset_events[12][4], [[11,14,per]]),
    (dataset_events[12][5], [[1,2,org],[7,7,per],[11,11,per],[13,14,per]]),
    (dataset_events[12][6], [[1,1,org],[19,19,per]]),
    (dataset_events[12][7], [[21,21,per],[31,31,org]]),
    (dataset_events[12][8], [[1,1,org],[6,8,org],[13,13,per],[21,21,org],[23,24,org]]),
    (dataset_events[12][9], [[3,4,per]]),
    (dataset_events[12][10], [[2,3,per]]),

    (dataset_events[11][0], []),
    (dataset_events[11][1], [[2,4,fac],[7,11,gpe]]),
    (dataset_events[11][2], []),
    (dataset_events[11][3], [[0,0,org],[2,3,per],[6,6,org],[9,11,org],[14,15,org],[40,40,org]]),
    (dataset_events[11][4], [[15,15,org],[28,29,org],[39,41,org]]),
    (dataset_events[11][5], [[1,1,org],[10,11,org],[16,17,org],[19,22,org]]),
    (dataset_events[11][6], [[2,4,org]]),
    (dataset_events[11][7], [[0,0,org],[2,2,per]]),
    (dataset_events[11][8], [[11,11,loc],[19,19,org]]),
    
    
    (dataset_events[10][0], [[3,3,org],[6,12,per],[17,17,org],[39,41,veh]]),
    (dataset_events[10][1], [[1,3,per],[7,7,per],[9,9,per],[16,16,org]]),
    (dataset_events[10][2], [[3,5,per],[19,19,org],[29,29,per],[31,31,per],[36,36,per],[40,40,org]]),
    (dataset_events[10][3], [[3,4,per],[6,6,gpe],[9,10,per]]),(dataset_events[9][0], [[3,3,org],[6,12,per],[17,17,org],[39,41,veh]]),
    (dataset_events[10][4], [[1,3,per],[7,7,per],[9,9,per],[16,16,org]]),
    (dataset_events[10][5], [[3,5,per],[19,19,org],[29,29,per],[31,31,per],[36,36,per],[40,40,org]]),
    (dataset_events[10][6], [[3,4,per],[6,6,gpe],[9,10,per]]),
    
    (dataset_events[9][0], [[3,3,org],[6,12,per],[17,17,org],[39,41,veh]]),
    (dataset_events[9][1], [[1,3,per],[7,7,per],[9,9,per],[16,16,org]]),
    (dataset_events[9][2], [[3,5,per],[19,19,org],[29,29,per],[31,31,per],[36,36,per],[40,40,org]]),
    (dataset_events[9][3], [[3,4,per],[6,6,gpe],[9,10,per]]),
    
    
    
    (dataset_events[8][0], [[0,3,gpe],[8,8,org]]),
    (dataset_events[8][1], [[0,4,per],[13,13,per],[16,16,org],[21,24,gpe],[32,32,per],[34,34,per]]),
    (dataset_events[8][2], [[6,7,org],[12,12,per],[33,37,org]]),
    (dataset_events[8][3], [[11,11,per],[13,13,per],[15,16,per],[21,21,per],[24,27,per],[34,34,org]]),
    (dataset_events[8][4], [[7,8,per],[12,14,per],[18,19,org],[21,21,per]]),
    (dataset_events[8][5], [[2,2,org],[14,14,per],[18,23,per]]),
    (dataset_events[8][6], [[3,3,org],[5,5,per]]),
    (dataset_events[8][7], [[7,7,org]]),
    (dataset_events[8][8], [[5,5,per]]),
    (dataset_events[8][9], [[0,4,org],[6,6,org],[9,10,per],[12,12,per],[24,24,per],[26,26,per]]),
    (dataset_events[8][10], [[2,2,per],[5,5,per],[10,10,per],[17,17,per],[22,23,per]]),
    (dataset_events[8][11], [[5,6,per],[11,12,per],[15,15,per]]),
    (dataset_events[8][12], [[1,1,org],[7,8,per]]),
    (dataset_events[8][13], [[1,2,org],[6,6,per],[10,11,gpe]]),
    (dataset_events[8][14], [[0,4,per],[14,14,per],[17,17,per],[28,28,org]]),
    (dataset_events[8][15], [[1,8,per],[20,20,per],[22,22,per],[7,7,per],[34,34,per]]),
    (dataset_events[8][16], [[1,1,per],[6,6,per]]),
    (dataset_events[8][17], [[1,1,org],[9,9,org]]),
    (dataset_events[8][18], [[3,3,per],[12,13,per],[17,17,per]]),
    (dataset_events[8][19], [[0,5,org],[24,24,per],[38,38,org]]),
    (dataset_events[8][20], [[2,2,per],[15,16,per]]),    
    (dataset_events[8][21], [[1,2,org],[6,7,gpe],[20,20,gpe],[22,22,gpe],[24,25,gpe]]), 
    (dataset_events[8][22], [[10,11,gpe],[17,17,per],[22,22,gpe]]), 
    (dataset_events[8][23], [[3,4,per],[6,7,gpe]]), 
    (dataset_events[8][24], [[2,3,per],[5,6,per]]), 
    
    
    
    (dataset_events[7][0], [[3,3,org],[6,6,org],[14,15,gpe],[17,18,org],[20,20,org],[28,29,gpe],
                            [35,36,org],[38,38,org],[41,43,org],[44,44,org],[52,54,veh],[61,61,org],[64,64,org]]),
    
    
    (dataset_events[6][0], [[1,1,org]]),
    (dataset_events[6][1], [[0,6,per],[10,12,per],[20,21,org],[28,30,org],[32,36,per]]),
    (dataset_events[6][2], []),
    (dataset_events[6][3], [[1,1,per],[15,15,org],[25,30,org],[31,31,org],[37,40,per]]),
    (dataset_events[6][4], [[1,1,org],[5,5,per],[18,18,per]]),
    (dataset_events[6][5], [[0,0,per],[6,7,org],[10,16,org],[32,32,per]]),
    (dataset_events[6][6], [[1,1,per],[26,31,org]]),
    (dataset_events[6][7], [[2,7,org],[13,13,loc],[18,18,per],[30,35,org],[38,38,per]]),
    (dataset_events[6][8], [[6,6,org],[9,9,per],[12,13,org]]),
    (dataset_events[6][9], [[1,1,org],[11,18,org],[20,20,org],[24,27,org],[32,32,org],[36,36,org]]),
    (dataset_events[6][10], [[1,1,per]]),
    (dataset_events[6][11], [[0,0,org],[6,6,per],[8,8,org]]),
    (dataset_events[6][12], [[1,2,org],[6,6,per]]),
    (dataset_events[6][13], [[1,1,per],[7,9,org],[17,18,per],[23,28,per],[32,35,per]]),
    (dataset_events[6][14], [[2,2,per],[7,9,org],[11,11,org],[16,16,org],[26,28,org],[36,38,per],
                             [41,41,org],[45,45,org],[52,52,per]]),
    (dataset_events[6][15], [[1,1,per],[4,5,per],[9,9,org],[18,19,per],[23,24,per],[28,30,per]]),
    (dataset_events[6][16], [[0,3,org],[8,8,org],[14,17,per],[19,24,per]]),
    (dataset_events[6][17], [[2,6,per],[16,19,per]]),
    (dataset_events[6][18], [[5,7,per],[12,15,per],[22,22,per],[25,25,org],[28,28,org],[37,37,org]]),
    
    (dataset_events[5][0], [[1,1,org]]),
    (dataset_events[5][1], [[10,12,per],[17,20,org],[26,28,per],[34,52,per]]),
    (dataset_events[5][2], []),
    (dataset_events[5][3], [[0,8,per],[14,15,org],[19,24,gpe]]),
    (dataset_events[5][4], [[0,0,org],[2,3,per],[5,5,per],[12,16,org],[23,34,per],[40,41,per],[43,49,per]]),
    (dataset_events[5][5], [[3,7,per]]),
    (dataset_events[5][6], [[0,1,per],[3,3,per],[7,11,org],[24,25,org]]),
    (dataset_events[5][7], [[0,4,org],[7,10,per],[13,13,per]]),
    (dataset_events[5][8], [[8,9,org]]),
    (dataset_events[5][9], [[10,15,per]]),
    (dataset_events[5][10], [[2,3,per]]),
    (dataset_events[5][11], [[1,1,per]]),
    (dataset_events[5][12], [[0,1,org],[17,17,per],[19,19,per],[21,21,per],[23,24,per],[30,30,org]]),
    (dataset_events[5][13], [[13,13,org]]),
    (dataset_events[5][14], []),
    (dataset_events[5][15], [[5,6,org],[10,10,org],[15,16,org],[26,26,org]]),
    (dataset_events[5][16], [[0,1,org],[13,13,org],[17,18,per]]),
    (dataset_events[5][17], [[0,0,per]]),
    (dataset_events[5][18], [[4,6,per],[9,9,org]]),
    (dataset_events[5][19], [[5,6,per],[13,16,per],[22,22,per]]),
    (dataset_events[5][20], [[5,7,per],[9,9,per],[16,20,org]]),
    (dataset_events[5][21], [[1,4,per],[13,17,per],[22,26,org]]),
    (dataset_events[5][22], [[4,7,org],[9,9,per],[21,21,per]]),
    (dataset_events[5][23], [[1,1,per],[11,12,org]]),
    (dataset_events[5][24], [[0,0,per],[5,5,org],[18,18,org],[23,25,per],[30,30,per]]),
    (dataset_events[5][25], [[0,1,org],[9,9,per],[16,18,per]]),
    (dataset_events[5][26], [[0,1,org],[10,11,per],[15,15,per],[17,17,per]]),
    (dataset_events[5][27], [[1,2,per],[4,5,org]]),
    (dataset_events[5][28], [[4,5,per],[9,13,per]]),
    (dataset_events[5][29], [[1,1,per],[9,10,per],[14,14,org]]),
    (dataset_events[5][30], [[9,20,per],[41,45,per],[50,51,org]]),
    (dataset_events[5][31], [[0,2,per]]),
    (dataset_events[5][32], [[1,9,per],[12,13,per],[18,18,per]]),
    (dataset_events[5][33], [[2,2,per],[5,5,per]]),
    (dataset_events[5][34], [[6,6,loc]]),
    (dataset_events[5][35], [[4,4,per],[6,6,org],[8,8,per],[11,11,org],[14,16,per],[20,20,per],[22,22,per],[27,27,per]]),
    (dataset_events[5][36], [[2,2,org],[10,11,org]]),
    (dataset_events[5][37], [[0,0,per],[7,11,org],[18,19,per]]),
    (dataset_events[5][38], []),
    (dataset_events[5][39], [[8,8,org]]),
    (dataset_events[5][40], [[9,9,org],[16,16,per]]),
    (dataset_events[5][41], [[4,4,per],[6,6,per],[13,18,per]]),
    (dataset_events[5][42], [[5,9,org],[13,13,per],[24,28,per],[31,31,per]]),
    
    
    (dataset_events[4][0], [[0,0,gpe],[2,2,org]]),
    (dataset_events[4][1], [[3,4,org],[10,11,org],[18,18,org],[36,36,per]]),
    (dataset_events[4][2], [[4,4,loc],[7,9,org],[17,17,per],[21,21,org],[25,25,per]]),
    (dataset_events[4][3], [[1,2,org],[8,10,org],[8,10,org],[13,13,per],[28,29,org],[36,37,gpe],[39,39,gpe]]),
    (dataset_events[4][4], [[1,1,org],[16,16,per],[18,21,per],[24,25,per]]),
    (dataset_events[4][5], []),
    (dataset_events[4][6], [[3,3,org],[19,19,per],[32,39,per],[47,47,org],[55,55,org],[68,70,org],[73,76,org],
                           [79,79,org],[90,90,org],[93,93,per],[104,104,org],[111,125,per]]),
    (dataset_events[4][7], [[5,8,org],[18,19,org]]),
    (dataset_events[4][8], []),
    (dataset_events[4][9], [[0,7,per],[10,10,org],[14,15,org],[18,22,org],[40,40,org]]),
    (dataset_events[4][10], [[2,3,per]]),
    (dataset_events[4][11], [[1,1,per],[6,6,org],[14,14,per]]),
    (dataset_events[4][12], [[0,2,per],[12,12,org]]),
    (dataset_events[4][13], [[0,1,gpe],[8,8,org],[16,17,per],[19,20,org],[21,21,org],[23,24,org]]),
    (dataset_events[4][14], [[0,0,per]]),
    (dataset_events[4][15], [[1,1,org],[7,8,org],[15,15,org],[28,29,org],[34,34,org],[39,42,org]]),
    (dataset_events[4][16], [[1,8,per],[19,19,org],[26,26,org],[36,36,org],[40,42,org]]),
    (dataset_events[4][17], [[6,7,org]]),
    (dataset_events[4][18], [[3,4,per]]),
    (dataset_events[4][19], [[0,6,per],[8,8,org],[22,22,org],[30,30,org],[33,33,per]]),
    (dataset_events[4][20], [[1,6,per],[11,11,org],[15,15,per],[31,32,org],[35,35,org],[47,47,per]]),
    
    
    
    
    
    (dataset_events[3][0], [[0,0,gpe],[2,2,org],[5,7,org],[10,12,org],[26,26,per]]),
    (dataset_events[3][1], []),
    (dataset_events[3][2], [[0,4,org],[21,21,per],[42,46,gpe]]),
    (dataset_events[3][3], [[0,0,org],[2,3,per],[15,15,fac],[26,26,per]]),
    (dataset_events[3][4], [[20,25,per]]),
    (dataset_events[3][5], [[5,5,org],[13,13,per]]),
    (dataset_events[3][6], [[3,3,org],[22,22,per],[24,24,per],[31,31,per]]),
    (dataset_events[3][7], [[10,14,org],[22,24,per]]),
    (dataset_events[3][8], [[5,6,gpe],[19,19,org]]),
    (dataset_events[3][9], [[0,0,gpe]]),
    (dataset_events[3][10], [[2,2,org],[26,28,org]]),
    (dataset_events[3][11], [[2,3,org]]),
    (dataset_events[3][12], [[1,1,per],[13,14,org],[16,16,gpe],[18,18,gpe]]),
    (dataset_events[3][13], [[3,3,org],[16,16,per]]),
    (dataset_events[3][14], [[1,1,org],[11,11,gpe]]),

    
    
    (dataset_events[2][0], [[6,6,gpe],[8,8,org],[11,12,gpe],[20,22,per],[28,31,veh],
                            [33,35,gpe],[40,40,per],[43,43,per]]),
    (dataset_events[2][1], [[1,10,per],[13,17,per]]),
    (dataset_events[2][2], [[3,4,org],[6,10,per],[15,16,per],[20,20,gpe],[23,23,per],[29,30,gpe]]),
    (dataset_events[2][3], [[11,12,gpe],[15,16,per],[25,25,per]]),
    (dataset_events[2][4], [[2,3,org],[5,5,per], [8,8,wea],[14,14,veh],[16,16,gpe],[18,18,gpe]]),
    (dataset_events[2][5], [[8,8,per], [11,12,org], [17,20,per]]),
    (dataset_events[2][6], [[2,2,per],[11,12,fac],[14,17,gpe], [21,23,per]]),
    (dataset_events[2][7], [[6,8,per],[13,13,gpe], [16,21,per],[23,25,per]]),
    (dataset_events[2][8], [[1,1,per], [7,7,gpe],[13,14,org],[19,19,gpe]]),
    (dataset_events[2][9], [[4,4,gpe], [12,12,gpe]]),
    (dataset_events[2][10], [[1,2,org], [4,4,per]]),
    (dataset_events[2][11], [[1,1,per], [10,10,per],[14,14,gpe],[29,29,per],[35,38,per]]),
    (dataset_events[2][12], [[2,3,org], [6,9,per], [12,12,per],[14,14,per],[18,19,per],[23,23,per]]),
    
    (dataset_events[1][0], []),
    (dataset_events[1][1], [[9,9,gpe],[10,10,fac],[12,13,org],[15,15,gpe]]),
    (dataset_events[1][2], [[0,0,org]]),
    (dataset_events[1][3], [[0,1,per],[6,7,gpe],[9,9,org],[12,15,org],[20,22,org],[26,26,per], [29,30,org],[33,35,org] ]),
    (dataset_events[1][4], [[1,8,per],[13,14,org]]),
    (dataset_events[1][5], [[1,1,org], [7,7,org], [9,12,org], [30,30,org]]),
    (dataset_events[1][6], [[1,7,org],[16,17,org]]),
    (dataset_events[1][7], [[0,1,per],[4,8,per], [12,12,per],[24,25,per],[29,30,per]]),
    (dataset_events[1][8], [[10,12,org], [17,18,org],[20,21,org],[24,24,org],[27,27,per],[29,29,per]]),
    (dataset_events[1][9], [[8,14,org], [27,27,per]]),
    
    
    (dataset_events[0][0], [[0,0,gpe], [2,2,org], [5,5,gpe], [6,7,per], 
                            [8,9,per], [23,23,gpe],[33,33,per],[35,35,fac]]),
    (dataset_events[0][1], []),
    (dataset_events[0][2], [[2,2,per],[4,4,gpe],[15,15,org], [22,22,per], [25,25,org], [34,34,gpe]]),
    (dataset_events[0][3], [[14,15,per]]),
    (dataset_events[0][4], []),
    (dataset_events[0][5], [[3,3,per], [6,6,gpe], [7,8,per], [13,13,per]]),
    (dataset_events[0][6], []),
    (dataset_events[0][7], []),
    (dataset_events[0][8], [[16,16,loc]]),
    (dataset_events[0][9], [[1,1,per], [10,10,gpe]]),
    (dataset_events[0][10], [[1,1,per],[3,3,gpe],[21,21,fac]]),
    (dataset_events[0][11], [[3,3,org],[5,5,org] ]),
    (dataset_events[0][12], [[3,3,per],[6,6,veh]]),
    (dataset_events[0][13], []),
    (dataset_events[0][14], [[13,13,gpe]]),
    (dataset_events[0][15], [[1,1,per]]),
    (dataset_events[0][16], [[6,6,fac]]),
    (dataset_events[0][17], [[2,2,per],[7,7,per], [15,15,gpe]]),
    (dataset_events[0][18], [[2,4,per], [7,7,gpe],]),
    (dataset_events[0][19], [[18,18,org], [20,20,gpe]]),
    (dataset_events[0][20], [[1,1,gpe],[2,6,per],[8,8,per],[19,22,org]])
    

    
]

dicto2=[(dataset_events[344][27], [[3,4,per],[6,6,gpe],[8,8,gpe],[10,11,gpe],[13,14,gpe],[17,18,per],[20,21,per],[23,24,per]]),
    (dataset_events[344][26], [[2,2,per]]),
    (dataset_events[344][25], [[12,12,per],[31,31,wea],[36,37,per],[40,43,org],[46,46,org]]),
    (dataset_events[344][24], [[4,4,per],[6,8,org],[14,15,fac],[21,21,org],[27,27,wea]]),
    (dataset_events[344][23], [[6,6,org],[13,13,org],[20,20,org],[22,23,per],[29,29,wea],[36,36,org]]),
    (dataset_events[344][22], [[3,3,org]]),
    (dataset_events[344][21], [[0,1,org],[7,7,org],[10,10,wea],[14,14,org]]),
    (dataset_events[344][20], [[3,3,fac],[5,8,org],[10,11,org],[20,21,org],[23,23,org],[26,27,org],[33,34,org],[33,34,org]]),
    (dataset_events[344][19], [[0,0,per],[4,4,per],[6,8,org],[13,13,org],[16,17,fac],[25,25,org]]),
    (dataset_events[344][18], [[3,3,org],[11,11,per],[15,15,wea]]),
    (dataset_events[344][17], [[1,1,per],[5,6,per],[8,8,per],[9,10,per],[19,19,org],[25,25,per]]),
    (dataset_events[344][16], [[1,3,org],[6,6,per],[11,11,per],[14,14,per],[15,16,per],[24,25,org],[34,36,org],[37,37,per]]),
    (dataset_events[344][15], [[0,0,org],[3,3,per],[7,7,wea],[11,11,wea],[15,17,org],[20,20,gpe],[26,26,per],[29,29,per]]),
    (dataset_events[344][14], [[4,5,fac],[10,10,org],[16,16,per],[21,21,org],[29,29,org]]),
    (dataset_events[344][13], [[8,8,org],[20,20,org],[27,27,per],[31,31,org]]),
    (dataset_events[344][12], [[6,6,org],[12,12,per],[14,16,org],[20,20,org],[29,29,org],[32,32,org]]),
    (dataset_events[344][11], [[0,0,org],[4,4,org],[8,8,org],[11,11,wea],[12,12,org]]),
    (dataset_events[344][10], [[1,1,per],[3,3,org],[5,8,org],[10,10,org],[12,13,fac],[14,14,per]]),
    (dataset_events[344][9], [[1,3,org],[10,10,per]]),
    (dataset_events[344][8], [[1,3,org],[11,12,fac]]),
    (dataset_events[344][7], [[0,0,per],[4,4,org]]),
    (dataset_events[344][6], [[1,1,per],[4,5,org],[9,11,org],[17,17,wea],[19,20,per]]),
    (dataset_events[344][5], [[7,7,fac],[10,10,gpe],[12,12,gpe],[19,19,wea],[26,27,per],[32,32,gpe],[3,3,org],[41,41,wea]]),
    (dataset_events[344][4], [[1,2,per],[4,6,org],[8,9,per],[16,16,org],[33,34,org],[49,49,wea]]),
    (dataset_events[344][3], [[8,10,org],[16,16,gpe],[17,17,org],[26,27,org],[30,30,org],[33,33,wea],[35,35,per]]),
    (dataset_events[344][2], [[7,7,fac],[9,9,org]]),
    (dataset_events[344][1], [[2,2,org],[18,18,org],[22,22,org],[29,29,org],[47,48,per]]),
    (dataset_events[344][0], [[0,0,gpe],[2,3,gpe],[8,8,org],[11,14,org],[22,24,org],[31,31,wea],[37,37,gpe],[38,38,org],[49,49,wea],[51,51,per]]),
    (dataset_events[343][3], [[2,3,per]]),
    (dataset_events[343][2], [[3,4,per],[6,6,gpe]]),
    (dataset_events[343][1], [[1,3,org],[12,13,org],[22,22,org],[25,26,gpe],[36,36,gpe],[37,37,per]]),
    (dataset_events[343][0], [[3,3,org],[6,10,org],[19,19,per]]),
    (dataset_events[342][13], [[1,1,org],[6,6,loc],[10,10,org],[23,23,per]]),
    (dataset_events[342][12], [[2,2,per],[8,9,per],[12,12,per],[14,14,org],[20,21,per],[24,24,per]]),
    (dataset_events[342][11], [[0,0,per],[13,13,org],[15,15,per]]),
    (dataset_events[342][10], [[11,11,per],[11,12,per],[28,28,org],[30,30,org],[39,39,org]]),
    (dataset_events[342][9], [[0,0,per],[3,3,org],[4,4,per],[7,7,per]]),
    (dataset_events[342][8], [[1,1,org],[3,3,org],[12,12,gpe],[13,13,org],[19,19,org],[20,22,per],[23,24,per],[27,27,org],[28,28,per],[31,31,per],[34,35,org],[37,37,org],[40,42,org],[46,46,per]]),
    (dataset_events[342][7], []),
    (dataset_events[342][6], [[6,7,org],[9,9,org],[25,25,per]]),
    (dataset_events[342][5], [[0,0,org],[5,5,org],[12,12,org]]),
    (dataset_events[342][4], [[1,1,per],[3,3,org],[10,10,org]]),
    (dataset_events[342][3], [[0,1,per],[4,4,org],[7,8,org],[9,9,org],[14,16,org],[20,20,per],[21,22,per],[31,31,per],[38,38,org]]),
    (dataset_events[342][2], [[0,0,org]]),
    (dataset_events[342][1], [[0,1,org],[2,2,per],[3,4,per],[7,7,gpe],[8,8,per],[16,16,gpe],[18,18,gpe]]),
    (dataset_events[342][0], []),
    (dataset_events[341][1], [[2,2,gpe],[4,4,org],[12,13,per],[24,24,gpe]]),
    (dataset_events[341][0], [[3,3,org],[6,8,org],[13,13,per],[16,16,org],[27,29,org]]),
    (dataset_events[340][72], [[0,0,per]]),
    (dataset_events[340][71], [[2,2,per]]),
    (dataset_events[340][70], [[3,4,org]]),
    (dataset_events[340][69], [[1,1,per]]),
    (dataset_events[340][68], [[14,14,per]]),
    (dataset_events[340][67], [[11,11,org]]),
    (dataset_events[340][66], [[1,2,per],[4,6,per],[8,10,per],[12,14,org],[16,17,gpe],[22,22,org],[32,32,org]]),
    (dataset_events[340][65], [[15,15,fac]]),
    (dataset_events[340][64], [[0,0,org]]),
    (dataset_events[340][63], [[1,2,per],[4,6,per],[9,10,org],[12,12,gpe]]),
    (dataset_events[340][62], [[0,0,per]]),
    (dataset_events[340][61], [[1,1,per]]),
    (dataset_events[340][60], [[14,14,org],[23,23,per],[25,25,per]]),
    (dataset_events[340][59], [[12,12,per]]),
    (dataset_events[340][58], [[5,5,org]]),
    (dataset_events[340][57], [[4,4,org],[6,6,org]]),
    (dataset_events[340][56], [[6,6,per],[18,18,org],[20,20,gpe]]),
    (dataset_events[340][55], [[9,9,per],[19,19,per]]),
    (dataset_events[340][54], [[2,2,org]]),
    (dataset_events[340][53], [[19,19,per]]),
    (dataset_events[340][52], [[10,10,per]]),
    (dataset_events[340][51], [[10,10,org],[14,14,per]]),
    (dataset_events[340][50], [[3,3,per]]),
    (dataset_events[340][49], [[1,1,org]]),
    (dataset_events[340][48], [[2,2,per],[6,6,per],[10,10,per]]),
    (dataset_events[340][47], [[14,14,org]]),
    (dataset_events[340][46], [[1,2,per],[4,6,per],[8,10,org],[12,12,gpe],[24,24,org],[26,26,org]]),
    (dataset_events[340][45], [[13,13,org]]),
    (dataset_events[340][44], [[8,8,org],[13,13,gpe],[18,18,per]]),
    (dataset_events[340][43], [[7,7,per]]),
    (dataset_events[340][42], [[4,4,org],[10,10,org],[11,12,org]]),
    (dataset_events[340][41], [[4,4,org],[24,24,org]]),
    (dataset_events[340][40], [[11,11,org]]),
    (dataset_events[340][39], [[0,0,per]]),
    (dataset_events[340][38], [[5,5,org]]),
    (dataset_events[340][37], [[13,13,per]]),
    (dataset_events[340][36], [[10,10,per],[14,14,per],[18,18,org]]),
    (dataset_events[340][35], [[1,2,gpe]]),
    (dataset_events[340][34], [[1,2,per],[4,6,per],[8,9,org]]),
    (dataset_events[340][33], [[3,3,gpe]]),
    (dataset_events[340][32], []),
    (dataset_events[340][31], [[1,2,per],[4,4,per],[6,8,org],[9,11,org],[13,15,org],[17,19,org]]),
    (dataset_events[340][30], [[6,6,org],[10,10,org],[31,31,org],[38,38,org],[59,59,per]]),
    (dataset_events[340][29], []),
    (dataset_events[340][28], []),
    (dataset_events[340][27], [[2,2,org]]),
    (dataset_events[340][26], [[0,0,org]]),
    (dataset_events[340][25], [[0,0,per]]),
    (dataset_events[340][24], []),
    (dataset_events[340][23], []),
    (dataset_events[340][22], [[1,1,org]]),
    (dataset_events[340][21], [[2,2,gpe]]),
    (dataset_events[340][20], [[8,8,org],[18,18,org]]),
    (dataset_events[340][19], [[1,2,per],[4,5,per],[7,9,per],[11,12,gpe]]),
    (dataset_events[340][18], [[0,0,per],[5,5,org],[16,16,org],[24,24,per]]),
    (dataset_events[340][17], [[11,11,org],[27,27,org]]),
    (dataset_events[340][16], []),
    (dataset_events[340][15], [[22,22,org],[30,30,org],[44,44,org]]),
    (dataset_events[340][14], [[5,6,org],[11,11,org],[27,27,org],[48,48,per]]),
    (dataset_events[340][13], [[1,1,org],[9,9,org]]),
    (dataset_events[340][12], [[1,2,per],[1,2,per],[4,4,per],[6,8,org],[10,10,gpe],[11,13,org],[19,19,org]]),
    (dataset_events[340][11], [[3,3,org],[25,25,gpe],[26,26,org]]),
    (dataset_events[340][10], [[5,6,org],[10,10,org],[23,25,org],[28,29,gpe],[30,31,org],[35,35,org],[43,43,per],[46,46,per]]),
    (dataset_events[340][9], [[2,2,org],[17,19,org],[23,23,org],[27,27,org],[30,31,per],[40,40,per]]),
    (dataset_events[340][8], []),
    (dataset_events[340][7], [[9,9,gpe],[10,11,org],[17,18,org],[20,20,org]]),
    (dataset_events[340][6], [[11,13,org]]),
    (dataset_events[340][5], [[1,1,org]]),
    (dataset_events[340][4], [[0,0,org],[2,3,per],[21,22,org],[31,31,org],[39,40,org]]),
    (dataset_events[340][3], [[1,1,org],[9,9,org],[11,11,fac],[14,14,gpe],[16,16,gpe],[18,18,gpe]]),
    (dataset_events[340][2], []),
    (dataset_events[340][1], [[1,1,gpe],[2,3,org],[6,6,gpe],[12,13,org],[15,15,org]]),
    (dataset_events[340][0], [[1,1,org]]),
    (dataset_events[339][25], [[6,6,gpe],[7,8,per],[9,10,per]]),
    (dataset_events[339][24], [[6,6,org],[7,7,per],[8,9,per],[11,12,per],[14,14,gpe],[15,16,per],[17,18,per],[39,39,per],[41,42,org]]),
    (dataset_events[339][23], [[1,1,org],[20,20,per],[23,23,org],[26,27,org],[35,35,org]]),
    (dataset_events[339][22], []),
    (dataset_events[339][21], [[1,1,org],[2,2,per],[4,4,gpe],[5,5,org],[8,11,org],[13,13,per],[14,15,org],[21,21,per],[36,36,org]]),
    (dataset_events[339][20], []),
    (dataset_events[339][19], [[6,6,gpe],[7,7,per],[8,9,per],[12,12,org],[17,17,org],[29,29,org],[36,36,org]]),
    (dataset_events[339][18], [[3,3,org],[5,6,org],[7,7,org],[24,24,org]]),
    (dataset_events[339][17], [[6,7,org],[9,10,org],[17,17,org],[6,7,org],[9,10,org],[17,17,org]]),
    (dataset_events[339][16], [[1,3,org],[9,9,org],[14,14,org],[28,28,org]]),
    (dataset_events[339][15], []),
    (dataset_events[339][14], [[0,0,org],[9,9,org],[10,10,per],[16,16,per],[33,33,org]]),
    (dataset_events[339][13], []),
    (dataset_events[339][12], [[0,1,org],[3,3,org],[4,4,org],[21,21,org],[27,27,org]]),
    (dataset_events[339][11], []),
    (dataset_events[339][10], [[0,0,org],[2,4,org]]),
    (dataset_events[339][9], [[0,1,org],[2,2,org],[8,8,org],[19,19,org],[25,25,org],[30,30,org]]),
    (dataset_events[339][8], []),
    (dataset_events[339][7], []),
    (dataset_events[339][6], [[15,15,org],[24,24,per]]),
    (dataset_events[339][5], [[1,1,org],[9,9,org],[14,14,per]]),
    (dataset_events[339][4], []),
    (dataset_events[339][3], [[5,9,org],[22,22,org]]),
    (dataset_events[339][2], [[0,0,org],[2,3,per]]),
    (dataset_events[339][1], [[1,1,org],[12,12,gpe],[14,14,gpe]]),
    (dataset_events[339][0], [[0,0,gpe],[2,2,org],[5,6,org],[11,11,gpe],[12,12,org],[23,24,org],[32,32,org]]),
    (dataset_events[338][1], [[1,1,org],[25,26,veh]]),
    (dataset_events[338][0], [[0,0,gpe],[5,5,org],[8,8,org],[9,9,org],[10,13,org],[23,23,per],[30,30,org]]),
    (dataset_events[337][5], [[1,1,org]]),
    (dataset_events[337][4], [[25,25,org]]),
    (dataset_events[337][3], [[0,0,org],[8,8,org],[35,36,org],[40,40,gpe]]),
    (dataset_events[337][2], [[0,0,org],[2,3,per],[8,8,org],[10,10,org],[15,16,org],[19,22,org],[30,30,gpe],[34,34,org],[45,45,org],[51,52,org]]),
    (dataset_events[337][1], [[1,1,org],[4,4,gpe],[6,6,gpe]]),
    (dataset_events[337][0], []),
    (dataset_events[336][4], [[3,4,per],[6,7,per],[10,12,per]]),
    (dataset_events[336][3], []),
    (dataset_events[336][2], [[1,1,org],[6,6,gpe],[20,22,org],[24,24,gpe],[1,1,org]]),
    (dataset_events[336][1], [[1,1,gpe],[2,2,org],[4,4,gpe],[6,6,org],[7,7,org]]),
    (dataset_events[336][0], [[0,0,gpe],[5,5,org]]),
    (dataset_events[335][27], [[1,1,org],[6,6,org],[11,11,org],[21,21,gpe],[26,26,per],[28,28,gpe]]),
    (dataset_events[335][26], [[1,1,gpe],[3,3,org],[9,10,per]]),
    (dataset_events[335][25], [[0,0,per]]),
    (dataset_events[335][24], [[9,9,org],[12,12,org],[16,16,per]]),
    (dataset_events[335][23], [[0,0,org],[17,17,per]]),
    (dataset_events[335][22], [[1,1,org],[11,11,org],[13,14,org],[24,25,org],[27,28,org],[30,33,org],[35,35,org]]),
    (dataset_events[335][21], [[1,1,per],[3,3,org],[19,20,gpe],[23,23,org],[29,29,org]]),
    (dataset_events[335][20], [[1,2,per],[5,6,per],[8,8,gpe],[9,10,org],[11,11,org],[14,16,per],[20,20,per],[22,22,gpe],[23,25,org],[26,26,org],[34,34,org],[39,39,org]]),
    (dataset_events[335][19], [[1,1,org],[11,11,loc],[15,15,gpe],[17,18,gpe],[29,30,gpe]]),
    (dataset_events[335][18], []),
    (dataset_events[335][17], [[3,3,per],[6,6,loc],[37,37,per]]),
    (dataset_events[335][16], []),
    (dataset_events[335][15], [[15,15,org]]),
    (dataset_events[335][14], [[1,2,per],[4,4,org],[6,6,fac],[20,21,org],[22,22,org]]),
    (dataset_events[335][13], [[1,1,org],[4,4,per],[29,29,per],[31,31,org]]),
    (dataset_events[335][12], [[1,1,org]]),
    (dataset_events[335][11], [[1,1,gpe],[3,4,org],[10,11,org]]),
    (dataset_events[335][10], []),
    (dataset_events[335][9], [[5,6,org],[10,10,per],[13,13,org],[24,24,org]]),
    (dataset_events[335][8], [[0,1,org],[7,7,per]]),
    (dataset_events[335][7], [[1,1,org],[12,12,org],[15,17,org],[18,19,org],[27,27,fac],[30,31,loc],[33,36,gpe]]),
    (dataset_events[335][6], [[0,0,org],[6,6,org],[12,12,gpe],[13,17,org],[20,20,org],[22,22,gpe]]),
    (dataset_events[335][5], [[1,1,per],[5,5,per],[7,7,per],[17,18,per],[20,20,org],[22,23,per]]),
    (dataset_events[335][4], [[0,1,per],[14,14,org],[34,34,gpe],[43,43,org]]),
    (dataset_events[335][3], [[0,0,org]]),
    (dataset_events[335][2], []),
    (dataset_events[335][1], [[5,5,org],[9,10,org],[19,19,gpe],[21,21,gpe]]),
    (dataset_events[335][0], [[0,0,gpe],[2,2,gpe],[4,4,org],[7,8,per],[10,10,org],[24,25,gpe],[29,29,org],[31,34,gpe]]),
    (dataset_events[334][25], [[1,1,org],[12,13,per]]),
    (dataset_events[334][24], [[25,25,org]]),
    (dataset_events[334][23], [[2,5,org],[24,24,per]]),
    (dataset_events[334][22], [[0,0,per],[2,2,org],[22,22,fac],[26,26,org]]),
    (dataset_events[334][21], [[4,4,org],[12,12,per],[15,16,org]]),
    (dataset_events[334][20], []),
    (dataset_events[334][19], [[2,2,org],[14,14,fac]]),
    (dataset_events[334][18], [[1,1,fac],[3,4,per]]),
    (dataset_events[334][17], [[6,7,per],[10,10,gpe]]),
    (dataset_events[334][16], [[1,1,org],[4,4,fac],[7,8,gpe],[16,17,fac]]),
    (dataset_events[334][15], [[0,0,per]]),
    (dataset_events[334][14], [[5,5,per]]),
    (dataset_events[334][13], [[0,0,per],[2,2,per]]),
    (dataset_events[334][12], [[5,5,per]]),
    (dataset_events[334][11], [[3,4,per],[8,9,per],[12,12,fac],[19,20,per],[22,23,per],[33,33,org],[39,39,org],[42,42,org]]),
    (dataset_events[334][10], []),
    (dataset_events[334][9], [[9,9,org],[15,16,org],[19,19,org],[28,28,fac],[39,40,per]]),
    (dataset_events[334][8], [[7,9,fac],[16,16,per]]),
    (dataset_events[334][7], []),
    (dataset_events[334][6], [[1,1,org],[19,19,per],[21,21,per]]),
    (dataset_events[334][5], [[5,5,per],[36,36,org]]),
    (dataset_events[334][4], [[6,6,org],[10,11,org],[20,23,org],[25,25,per]]),
    (dataset_events[334][3], [[0,1,per],[3,4,per],[6,6,per],[8,10,org],[32,32,per],[35,35,org]]),
    (dataset_events[334][2], [[0,0,org]]),
    (dataset_events[334][1], [[1,1,per],[8,9,fac],[12,14,fac],[16,16,gpe],[18,18,gpe],[20,20,gpe]]),
    (dataset_events[334][0], [[0,0,gpe],[2,2,org],[5,6,org],[14,15,fac],[27,27,per]]),
    (dataset_events[333][15], [[1,1,org],[6,6,per],[16,17,gpe]]),
    (dataset_events[333][14], []),
    (dataset_events[333][13], [[20,20,org]]),
    (dataset_events[333][12], [[9,9,org],[12,14,org],[18,18,gpe],[21,21,org],[23,23,per],[26,26,org],[28,28,org],[36,36,org]]),
    (dataset_events[333][11], [[5,5,org],[20,20,per],[29,29,org]]),
    (dataset_events[333][10], [[11,11,per],[21,21,gpe]]),
    (dataset_events[333][9], [[8,8,org],[15,15,per],[16,17,per],[24,24,per],[28,28,per],[31,31,per],[34,34,org],[36,36,gpe],[46,48,per],[49,50,per]]),
    (dataset_events[333][8], [[0,0,org],[1,1,per],[2,3,per],[7,10,per]]),
    (dataset_events[333][7], [[0,0,per],[3,3,org],[9,9,per],[14,14,per],[20,23,org],[35,35,fac]]),
    (dataset_events[333][6], [[1,1,per],[7,7,org],[10,12,org],[14,14,org],[27,27,per],[29,29,per]]),
    (dataset_events[333][5], [[1,1,org]]),
    (dataset_events[333][4], [[5,5,org]]),
    (dataset_events[333][3], [[1,1,org],[3,3,org],[34,34,per],[36,36,per]]),
    (dataset_events[333][2], [[4,4,org],[6,7,fac],[11,11,per],[20,21,fac],[24,24,per],[26,26,per],[30,30,org],[35,35,org]]),
    (dataset_events[333][1], [[10,10,per],[16,17,per],[20,20,org],[27,30,org],[31,32,per],[35,35,org]]),
    (dataset_events[333][0], [[0,0,gpe],[2,2,org],[5,7,org],[8,8,org],[21,21,org],[27,27,per]]),
    (dataset_events[332][3], [[3,4,per],[6,6,gpe],[9,10,per]]),
    (dataset_events[332][2], [[2,2,org],[22,22,org],[20,21,org],[34,35,per],[38,39,per]]),
    (dataset_events[332][1], [[1,1,org],[2,3,per],[8,7,org],[14,14,org],[26,26,org]]),
    (dataset_events[332][0], [[3,3,org],[6,7,org],[13,14,org],[29,30,org],[40,41,org]]),
    (dataset_events[331][3], [[64,66,org],[108,110,org],[123,125,org],[158,158,org]]),
    (dataset_events[331][2], []),
    (dataset_events[331][1], [[0,0,org]]),
    (dataset_events[331][0], [[3,3,org],[6,9,org],[13,13,org]]),
    (dataset_events[330][4], [[2,3,per]]),
    (dataset_events[330][3], [[3,4,per]]),
    (dataset_events[330][2], [[6,8,fac]]),
    (dataset_events[330][1], [[0,0,gpe],[5,5,org]]),
    (dataset_events[330][0], [[0,0,gpe],[5,5,org],[8,10,org]]),
    (dataset_events[329][7], [[5,6,org],[9,9,org],[11,11,org],[13,13,org],[23,23,org]]),
    (dataset_events[329][6], [[1,1,per],[11,12,org],[38,39,per],[49,49,org]]),
    (dataset_events[329][5], [[0,0,org],[24,25,org]]),
    (dataset_events[329][4], [[6,6,org],[8,8,org],[14,15,org],[23,23,org],[25,25,org]]),
    (dataset_events[329][3], [[19,19,org],[20,20,org],[26,27,org]]),
    (dataset_events[329][2], [[0,0,org],[2,3,per],[9,9,org],[12,13,org],[15,15,org],[16,17,org],[18,18,org],[22,22,org],[28,29,per],[46,46,org],[59,59,gpe]]),
    (dataset_events[329][1], [[1,1,org],[4,4,org],[12,12,fac],[15,18,org],[20,20,org],[23,24,gpe],[26,26,gpe]]),
    (dataset_events[329][0], []),
    (dataset_events[328][7], [[3,5,org]]),
    (dataset_events[328][6], [[21,22,org],[25,25,org]]),
    (dataset_events[328][5], [[0,0,org],[2,3,org]]),
    (dataset_events[328][4], []),
    (dataset_events[328][3], [[5,6,per],[8,8,org],[22,24,org],[28,28,org],[30,31,org],[33,36,org],[42,43,org]]),
    (dataset_events[328][2], [[1,1,org],[10,12,org],[30,32,org]]),
    (dataset_events[328][1], [[5,6,org],[11,11,fac],[16,16,org],[20,20,org]]),
    (dataset_events[328][0], [[6,6,gpe],[8,8,org],[11,13,org],[26,28,org],[33,33,per],[34,35,org],[34,36,org],[39,41,org]]),
    (dataset_events[327][19], [[8,9,org],[15,15,org],[21,21,gpe],[32,33,org],[35,36,org],[39,39,org]]),
    (dataset_events[327][18], [[1,1,org]]),
    (dataset_events[327][17], [[5,5,org],[7,7,org],[30,30,org],[34,34,gpe],[44,44,loc],[51,51,org],[52,54,per],[55,56,per]]),
    (dataset_events[327][16], [[0,0,org],[9,9,org],[14,14,org],[23,23,fac],[25,25,gpe]]),
    (dataset_events[327][15], [[8,8,org],[16,16,org]]),
    (dataset_events[327][14], [[1,1,org],[12,12,gpe],[13,13,org]]),
    (dataset_events[327][13], [[1,1,org],[6,6,gpe],[7,7,org]]),
    (dataset_events[327][12], [[5,5,org],[14,15,fac],[18,19,gpe]]),
    (dataset_events[327][11], [[0,0,org]]),
    (dataset_events[327][10], [[4,4,org],[19,19,per],[21,21,org],[33,33,org]]),
    (dataset_events[327][9], [[4,4,org],[14,15,gpe],[17,17,gpe]]),
    (dataset_events[327][8], [[4,4,org],[9,9,gpe],[13,13,org],[16,16,org]]),
    (dataset_events[327][7], [[1,1,org]]),
    (dataset_events[327][6], [[4,4,org],[15,15,org]]),
    (dataset_events[327][5], []),
    (dataset_events[327][4], []),
    (dataset_events[327][3], [[20,20,org],[22,22,gpe],[24,24,gpe],[26,26,fac]]),
    (dataset_events[327][2], [[0,1,org],[5,5,org]]),
    (dataset_events[327][1], []),
    (dataset_events[327][0], [[1,1,org],[4,5,org],[9,9,org],[12,13,org],[25,25,org]]),
    (dataset_events[326][9], [[1,1,org],[31,31,org],[31,32,org],[32,32,org],[34,35,org],[36,36,org]]),
    (dataset_events[326][8], [[1,3,org],[1,4,org],[5,5,org],[7,9,org],[9,9,org]]),
    (dataset_events[326][7], [[2,2,org],[18,20,fac],[33,33,org]]),
    (dataset_events[326][6], [[1,2,gpe],[4,5,org],[6,7,org],[6,8,org],[8,8,org],[10,11,org],[19,19,per]]),
    (dataset_events[326][5], [[11,11,per],[21,21,per]]),
    (dataset_events[326][4], [[10,10,gpe],[13,13,gpe],[19,19,per],[21,21,per],[24,24,org],[28,28,gpe],[29,29,org]]),
    (dataset_events[326][3], [[9,9,per],[32,32,per],[30,31,org],[32,32,per]]),
    (dataset_events[326][2], [[0,0,org],[2,3,per],[8,8,org],[11,14,org],[15,15,org],[51,51,org]]),
    (dataset_events[326][1], [[7,11,org],[12,13,fac],[15,17,gpe]]),
    (dataset_events[326][0], []),
    (dataset_events[325][24], [[2,3,per]]),
    (dataset_events[325][23], [[2,6,per],[8,9,per],[11,11,gpe]]),
    (dataset_events[325][22], [[2,2,org],[18,18,org]]),
    (dataset_events[325][21], [[13,13,org],[22,22,org]]),
    (dataset_events[325][20], [[0,0,org]]),
    (dataset_events[325][19], [[0,3,org],[17,17,per]]),
    (dataset_events[325][18], [[1,2,org],[8,9,org],[17,18,per],[19,21,per]]),
    (dataset_events[325][17], [[1,1,org],[3,4,org],[5,6,org],[31,31,gpe]]),
    (dataset_events[325][16], [[0,0,org],[2,3,org],[35,35,org]]),
    (dataset_events[325][15], []),
    (dataset_events[325][14], [[10,10,loc],[15,15,org]]),
    (dataset_events[325][13], [[6,6,gpe],[8,8,gpe],[18,19,per],[21,22,per],[24,24,org]]),
    (dataset_events[325][12], [[2,2,org],[16,16,gpe]]),
    (dataset_events[325][11], [[1,1,gpe],[2,2,org],[23,23,per],[24,25,per],[31,31,org]]),
    (dataset_events[325][10], [[1,1,org],[7,7,gpe],[9,9,gpe],[15,16,gpe],[30,30,org]]),
    (dataset_events[325][9], []),
    (dataset_events[325][8], [[7,10,org],[13,13,org],[19,21,org]]),
    (dataset_events[325][7], []),
    (dataset_events[325][6], [[10,12,org],[20,21,per],[27,27,per]]),
    (dataset_events[325][5], [[0,3,org],[9,9,org],[11,11,org]]),
    (dataset_events[325][4], [[1,2,org],[16,17,org],[20,21,per],[22,23,per],[34,34,org]]),
    (dataset_events[325][3], [[34,34,org],[40,40,org],[49,49,per],[68,68,gpe]]),
    (dataset_events[325][2], [[0,0,org]]),
    (dataset_events[325][1], [[0,0,org]]),
    (dataset_events[325][0], [[7,7,gpe]]),
    (dataset_events[324][2], []),
    (dataset_events[324][1], [[1,2,per],[5,5,per],[7,8,per],[10,11,org],[15,18,org],[22,22,gpe],[28,28,per],[32,32,org],[34,34,fac]]),
    (dataset_events[324][0], [[1,3,org],[8,8,per],[11,14,per],[32,33,org],[34,35,fac],[42,43,org]]),
    (dataset_events[323][3], [[4,4,org],[21,23,org],[26,26,gpe]]),
    (dataset_events[323][2], [[0,0,org],[2,3,per],[5,5,gpe],[7,7,org],[10,10,org],[22,22,fac],[24,24,gpe],[30,31,org],[34,36,org]]),
    (dataset_events[323][1], [[3,3,org],[8,10,fac],[13,14,gpe],[16,17,gpe],[24,24,org],[30,31,fac]]),
    (dataset_events[323][0], []),
    (dataset_events[322][29], [[1,1,per],[13,13,per]]),
    (dataset_events[322][28], [[2,2,per],[8,8,per]]),
    (dataset_events[322][27], [[1,1,gpe]]),
    (dataset_events[322][26], [[1,1,per],[4,4,per],[10,10,per],[19,20,gpe]]),
    (dataset_events[322][25], [[1,2,org],[7,7,gpe],[16,16,per],[24,24,per],[29,29,org],[40,41,loc],[44,45,per],[47,47,per],[50,50,gpe],[52,56,org]]),
    (dataset_events[322][24], [[2,2,per],[26,26,per]]),
    (dataset_events[322][23], []),
    (dataset_events[322][22], [[1,2,org],[4,5,per],[7,7,gpe],[9,14,org],[18,18,gpe]]),
    (dataset_events[322][21], [[3,6,per],[18,19,per],[21,22,per],[25,26,per],[29,29,per],[32,35,org],[38,39,per],[41,44,org]]),
    (dataset_events[322][20], [[1,3,org],[22,22,per],[22,22,per],[26,26,per],[28,28,per],[30,30,per],[32,32,per]]),
    (dataset_events[322][19], [[1,1,org],[3,4,org],[6,6,org],[17,19,per],[25,25,per]]),
    (dataset_events[322][18], [[10,10,gpe],[14,14,gpe],[21,21,per],[24,25,per],[38,38,per]]),
    (dataset_events[322][17], [[11,11,org]]),
    (dataset_events[322][16], [[17,17,per],[27,27,per],[29,30,fac],[38,39,per],[44,49,org],[51,51,org]]),
    (dataset_events[322][15], [[0,3,per]]),
    (dataset_events[322][14], []),
    (dataset_events[322][13], [[6,6,gpe],[8,8,per]]),
    (dataset_events[322][12], [[3,4,org],[11,11,gpe]]),
    (dataset_events[322][11], []),
    (dataset_events[322][10], [[16,16,gpe],[26,29,per]]),
    (dataset_events[322][9], [[2,3,org],[35,38,org]]),
    (dataset_events[322][8], [[1,1,gpe],[4,5,gpe],[23,24,org],[34,34,per],[36,36,org]]),
    (dataset_events[322][7], [[0,1,gpe],[15,15,per]]),
    (dataset_events[322][6], [[1,1,per]]),
    (dataset_events[322][5], [[8,8,per]]),
    (dataset_events[322][4], [[9,9,per]]),
    (dataset_events[322][3], [[2,2,per]]),
    (dataset_events[322][2], [[1,2,gpe],[7,7,gpe],[47,48,per],[51,54,per],[56,57,gpe]]),
    (dataset_events[322][1], [[0,0,org],[1,3,per],[35,36,org],[39,40,org]]),
    (dataset_events[322][0], [[0,1,org],[3,3,org]]),
    (dataset_events[321][21], []),
    (dataset_events[321][20], [[8,8,org]]),
    (dataset_events[321][19], []),
    (dataset_events[321][18], []),
    (dataset_events[321][17], [[6,6,org]]),
    (dataset_events[321][16], []),
    (dataset_events[321][15], [[29,29,per]]),
    (dataset_events[321][14], []),
    (dataset_events[321][13], []),
    (dataset_events[321][12], [[13,13,per],[16,16,org],[17,18,per]]),
    (dataset_events[321][11], [[1,1,org],[9,9,org]]),
    (dataset_events[321][10], []),
    (dataset_events[321][9], [[6,6,org],[33,33,per],[36,36,org],[37,38,per]]),
    (dataset_events[321][8], []),
    (dataset_events[321][7], []),
    (dataset_events[321][6], [[7,7,org]]),
    (dataset_events[321][5], [[13,16,org],[36,37,per]]),
    (dataset_events[321][4], [[0,0,org]]),
    (dataset_events[321][3], [[1,1,org]]),
    (dataset_events[321][2], []),
    (dataset_events[321][1], []),
    (dataset_events[321][0], [[6,6,org],[20,20,org]]),
    (dataset_events[320][16], [[4,4,org]]),
    (dataset_events[320][15], [[0,0,org],[5,5,org],[14,14,org]]),
    (dataset_events[320][14], [[6,6,org],[8,8,org],[23,23,org]]),
    (dataset_events[320][13], [[0,0,per],[6,6,org],[15,15,org]]),
    (dataset_events[320][12], [[0,0,org],[6,8,per],[11,12,org],[16,16,per]]),
    (dataset_events[320][11], [[0,0,per],[2,2,per],[6,6,org],[13,15,per],[19,22,per],[26,27,per]]),
    (dataset_events[320][10], [[2,2,per],[9,9,org],[22,24,gpe]]),
    (dataset_events[320][9], [[1,1,org],[8,8,per],[14,14,org],[32,34,org]]),
    (dataset_events[320][8], [[1,2,per],[6,9,org],[13,13,org],[26,28,per],[30,30,per],[46,46,per]]),
    (dataset_events[320][7], []),
    (dataset_events[320][6], [[3,3,org],[10,11,per],[27,29,per],[30,31,per]]),
    (dataset_events[320][5], [[1,1,per],[3,3,per],[3,3,org],[26,26,per]]),
    (dataset_events[320][4], [[0,1,org],[10,10,org]]),
    (dataset_events[320][3], [[1,1,org],[4,5,org],[7,7,per],[10,11,per],[32,33,org],[42,42,per]]),
    (dataset_events[320][2], [[0,1,per],[3,4,gpe],[6,6,gpe]]),
    (dataset_events[320][1], [[0,0,org]]),
    (dataset_events[320][0], [[3,3,org],[8,15,org],[17,17,gpe],[19,19,gpe]]),
    (dataset_events[319][18], [[4,7,org],[9,12,org],[14,16,org],[18,22,org],[31,34,org],[36,37,org]]),
    (dataset_events[319][17], []),
    (dataset_events[319][16], [[1,2,per],[7,7,org],[13,14,per],[16,16,gpe]]),
    (dataset_events[319][15], []),
    (dataset_events[319][14], [[2,2,org]]),
    (dataset_events[319][13], [[1,1,org],[10,14,org],[17,23,org],[29,31,org]]),
    (dataset_events[319][12], [[12,13,org],[19,20,org]]),
    (dataset_events[319][11], [[9,13,org],[12,13,org],[22,22,gpe]]),
    (dataset_events[319][10], [[1,1,org],[16,16,per],[20,21,org]]),
    (dataset_events[319][9], [[1,1,org],[10,11,gpe]]),
    (dataset_events[319][8], [[0,0,org]]),
    (dataset_events[319][7], [[5,5,org],[25,25,per],[27,27,per],[30,30,per]]),
    (dataset_events[319][6], [[1,1,gpe],[3,3,gpe],[6,6,org],[23,24,org]]),
    (dataset_events[319][5], [[0,0,org],[29,30,per],[33,36,org]]),
    (dataset_events[319][4], [[1,2,org],[35,35,per]]),
    (dataset_events[319][3], [[0,0,org],[2,3,per]]),
    (dataset_events[320][2], [[1,1,org],[7,7,fac],[9,10,fac],[12,13,gpe],[15,15,gpe]]),
    (dataset_events[319][1], []),
    (dataset_events[319][0], [[0,1,gpe],[3,3,org],[6,9,org],[18,18,per],[35,35,gpe],[36,38,org]]),
    (dataset_events[318][4], [[3,4,per]]),
    (dataset_events[318][3], [[7,7,per],[11,11,per],[14,14,gpe],[16,16,gpe],[20,20,gpe]]),
    (dataset_events[318][2], [[1,1,org]]),
    (dataset_events[318][1], [[2,2,org],[15,15,org]]),
    (dataset_events[318][0], [[0,1,gpe],[6,6,org],[9,11,org],[14,14,per],[15,16,per],[22,23,org]]),
    (dataset_events[317][16], [[2,3,per]]),
    (dataset_events[317][15], [[3,4,per]]),
    (dataset_events[317][14], []),
    (dataset_events[317][13], [[0,1,org]]),
    (dataset_events[317][12], [[1,2,org]]),
    (dataset_events[317][11], [[0,0,gpe],[18,20,org]]),
    (dataset_events[317][10], []),
    (dataset_events[317][9], [[0,0,gpe],[23,24,org]]),
    (dataset_events[317][8], []),
    (dataset_events[317][7], [[0,0,gpe],[15,15,gpe],[23,23,gpe]]),
    (dataset_events[317][6], [[9,9,org]]),
    (dataset_events[317][5], [[0,0,gpe],[4,4,org],[23,24,org]]),
    (dataset_events[317][4], [[0,0,per]]),
    (dataset_events[317][3], [[0,3,org],[8,8,gpe],[10,11,org],[18,19,gpe]]),
    (dataset_events[317][2], [[1,1,gpe],[7,7,gpe],[32,32,per]]),
    (dataset_events[317][1], [[11,11,gpe],[21,21,gpe],[37,37,gpe],[42,42,org]]),
    (dataset_events[317][0], [[1,1,gpe]]),
    (dataset_events[316][5], [[3,3,org]]),
    (dataset_events[316][4], [[0,1,org]]),
    (dataset_events[316][3], []),
    (dataset_events[316][2], []),
    (dataset_events[316][1], []),
    (dataset_events[316][0], [[0,1,org]]),
    (dataset_events[315][10], [[15,15,org]]),
    (dataset_events[315][9], [[3,3,org],[11,11,org],[16,17,org],[18,18,per],[19,20,per],[31,31,per]]),
    (dataset_events[315][8], [[8,8,org],[17,17,org],[24,24,org]]),
    (dataset_events[315][7], [[1,1,per],[10,11,org],[12,12,per]]),
    (dataset_events[315][6], [[11,11,gpe]]),
    (dataset_events[315][5], [[1,1,per],[6,6,gpe],[19,19,org],[21,21,org]]),
    (dataset_events[315][4], [[13,13,org],[10,10,per]]),
    (dataset_events[315][3], [[1,5,org],[19,20,org],[22,23,org]]),
    (dataset_events[315][2], [[0,0,org],[2,3,per],[6,6,org]]),
    (dataset_events[315][1], []),
    (dataset_events[315][0], [[3,3,org],[11,13,org],[19,24,org],[27,27,gpe],[29,29,gpe],[31,31,gpe]]),
    (dataset_events[314][3], [[1,1,org],[7,7,org],[16,16,per]]),
    (dataset_events[314][2], [[1,1,org],[10,11,org],[29,29,per],[39,40,org],[42,42,org]]),
    (dataset_events[314][1], [[0,0,org],[2,3,per],[11,11,org],[14,15,org],[24,25,org],[28,28,org],[42,42,per],[51,52,org]]),
    (dataset_events[314][0], [[29,29,org]]),
    (dataset_events[313][16], [[1,1,org],[3,3,fac]]),
    (dataset_events[313][15], [[1,1,org],[13,13,org]]),
    (dataset_events[313][14], [[1,1,org],[3,3,org],[21,21,org],[26,26,org],[31,31,org],[39,39,org]]),
    (dataset_events[313][13], [[0,1,org]]),
    (dataset_events[313][12], [[3,3,org],[5,5,org],[10,11,org],[13,13,org]]),
    (dataset_events[313][11], [[0,0,org],[5,5,org],[8,8,gpe],[11,12,org],[16,16,org],[19,21,fac],[24,24,gpe],[27,27,gpe]]),
    (dataset_events[313][10], [[3,3,per],[8,8,per],[12,12,per]]),
    (dataset_events[313][9], [[8,8,org],[11,11,per],[22,22,org],[23,23,per],[29,29,org],[48,49,org],[51,52,org],[55,55,org]]),
    (dataset_events[313][8], [[2,2,org],[26,26,per]]),
    (dataset_events[313][7], [[0,0,org],[14,14,org],[17,18,per],[19,20,per],[22,22,org]]),
    (dataset_events[313][6], [[3,4,org],[6,6,org],[20,20,per]]),
    (dataset_events[313][5], [[0,1,per],[3,3,org],[7,7,org],[13,15,fac],[17,17,gpe]]),
    (dataset_events[313][4], [[0,0,org]]),
    (dataset_events[313][3], []),
    (dataset_events[313][2], [[1,3,org],[5,5,fac],[9,9,gpe],[11,11,gpe],[13,13,gpe]]),
    (dataset_events[313][1], []),
    (dataset_events[313][0], [[1,1,org],[4,6,org],[7,8,org],[13,19,org],[23,24,org]]),
    (dataset_events[312][14], [[2,3,per],[5,7,per]]),
    (dataset_events[312][13], [[3,4,per]]),
    (dataset_events[312][12], [[3,3,org]]),
    (dataset_events[312][11], [[0,0,org],[2,2,per],[16,16,org],[28,30,org]]),
    (dataset_events[312][10], [[1,1,gpe],[4,4,org]]),
    (dataset_events[312][9], [[24,25,per],[26,27,per]]),
    (dataset_events[312][8], [[0,0,org],[7,7,org],[10,10,gpe]]),
    (dataset_events[312][7], [[10,11,fac],[13,14,loc],[16,17,gpe]]),
    (dataset_events[312][6], [[12,12,org]]),
    (dataset_events[312][5], [[3,3,org]]),
    (dataset_events[312][4], [[7,7,org],[14,15,per],[21,22,org]]),
    (dataset_events[312][3], [[1,1,org]]),
    (dataset_events[312][2], [[1,1,org], [3,5,org],[7,8,org],[13,14,org]]),
    (dataset_events[312][1], [[1,3,org]]),
    (dataset_events[312][0], [[11,11,gpe],[16,16,org],[19,21,org],[22,24,org],[39,40,org]]),
    (dataset_events[311][3], [[0,2,org],[5,5,per],[8,8,org]]),
    (dataset_events[311][2], []),
    (dataset_events[311][1], []),
    (dataset_events[311][0], [[3,3,org],[6,7,org]]),
    (dataset_events[310][0], [[3,3,org],[6,7,org],[31,31,org]]),
    (dataset_events[309][2], [[0,2,org],[14,14,loc],[26,26,org]]),
    (dataset_events[309][1], [[0,3,org]]),
    (dataset_events[309][0], [[3,3,org]]),
    (dataset_events[308][0], [[4,4,org]]),
    (dataset_events[308][19], [[0,0,per],[10,10,org],[13,13,org]]),
    (dataset_events[308][18], []),
    (dataset_events[308][17], [[2,2,org],[36,36,org],[39,39,org]]),
    (dataset_events[308][16], [[1,1,org],[5,5,per],[17,17,org]]),
    (dataset_events[308][15], [[3,3,gpe],[5,5,gpe],[7,7,gpe],[9,9,fac],[30,30,org]]),
    (dataset_events[308][14], [[1,1,org],[4,5,org],[20,21,org],[38,38,fac],[40,40,gpe]]),
    (dataset_events[308][13], [[0,1,org]]),
    (dataset_events[308][12], [[0,1,org]]),
    (dataset_events[308][11], [[3,5,org],[20,21,org]]),
    (dataset_events[308][10], [[1,1,org],[3,4,fac],[8,9,fac],[11,12,fac]]),
    (dataset_events[308][9], [[0,0,org],[11,11,org]]),
    (dataset_events[308][8], [[16,16,per],[24,24,fac]]),
    (dataset_events[308][7], [[9,10,org],[14,14,org],[16,17,fac]]),
    (dataset_events[308][6], [[2,2,org],[4,4,org]]),
    (dataset_events[308][5], [[23,25,per],[26,27,per]]),
    (dataset_events[308][4], [[1,2,org],[6,6,per],[12,12,per],[25,25,org]]),
    (dataset_events[308][3], [[0,0,org],[2,3,per]]),
    (dataset_events[308][2], [[1,2,org],[8,8,fac],[10,11,gpe],[13,13,gpe],[15,15,gpe]]),
    (dataset_events[308][1], []),
    (dataset_events[308][0], [[1,1,org],[4,5,org],[29,30,fac],[32,34,fac]]),
    (dataset_events[307][15], [[9,9,per]]),
    (dataset_events[307][14], [[2,2,org]]),
    (dataset_events[307][13], [[25,25,per]]),
    (dataset_events[307][12], [[1,3,org],[4,4,org],[9,11,org],[30,30,org],[33,33,org]]),
    (dataset_events[307][11], [[2,2,per],[5,6,org]]),
    (dataset_events[307][10], [[30,31,org]]),
    (dataset_events[307][9], [[5,6,per],[19,19,gpe],[21,21,org],[36,36,org]]),
    (dataset_events[307][8], [[24,24,org]]),
    (dataset_events[307][7], [[2,2,org],[11,14,org],[46,47,gpe],[50,50,org]]),
    (dataset_events[307][6], [[3,3,per],[5,5,per],[17,17,org],[24,24,org]]),
    (dataset_events[307][5], []),
    (dataset_events[307][4], [[2,3,org],[5,6,org],[21,22,org],[25,25,org]]),
    (dataset_events[307][3], [[0,1,per],[6,8,org],[21,21,org],[40,42,org],[44,44,org],[45,48,org],[51,51,org]]),
    (dataset_events[307][2], [[0,0,org]]),
    (dataset_events[307][1], [[10,10,per],[15,17,fac],[19,20,gpe],[22,22,gpe]]),
    (dataset_events[307][0], [[0,1,gpe],[3,3,org],[6,7,org],[8,8,org],[10,10,org],[15,15,org],[30,30,org],[47,47,org]]),
    (dataset_events[306][14], [[1,1,per],[10,10,per],[16,17,org],[19,19,org],[22,23,org],[29,29,org]]),
    (dataset_events[306][13], [[1,2,per],[7,11,org],[16,16,org],[26,26,org],[36,36,org]]),
    (dataset_events[306][12], [[1,3,per],[4,5,per],[7,7,org],[11,11,org],[23,23,per]]),
    (dataset_events[306][11], [[3,3,fac],[9,10,per],[12,13,per],[19,19,org],[22,22,veh],[32,33,org],[36,37,per],[40,42,org],[45,45,per],[47,47,org]]),
    (dataset_events[306][10], [[1,2,org],[12,15,veh]]),
    (dataset_events[306][9], [[0,0,org],[6,6,per],[11,11,gpe],[27,29,veh]]),
    (dataset_events[306][8], [[4,4,org],[8,8,veh],[14,17,per],[19,20,per],[23,23,org]]),
    (dataset_events[306][7], [[1,4,org],[9,12,org],[13,13,per],[14,15,per],[19,19,org],[28,28,veh]]),
    (dataset_events[306][6], [[1,2,org],[3,3,org],[35,35,org],[38,38,per],[46,46,veh],[48,49,org]]),
    (dataset_events[306][5], [[0,1,per],[4,4,per],[15,15,veh],[35,35,org],[37,37,org],[39,39,org]]),
    (dataset_events[306][4], [[0,0,org]]),
    (dataset_events[306][3], [[1,4,veh],[13,15,fac],[18,20,fac],[22,22,gpe],[24,24,gpe],[26,26,gpe]]),
    (dataset_events[306][2], []),
    (dataset_events[306][1], [[1,3,org],[11,13,per],[16,16,gpe],[25,25,org],[29,31,veh]]),
    (dataset_events[306][0], [[0,0,gpe],[2,2,org]]),
    (dataset_events[305][27], [[3,3,per]]),
    (dataset_events[305][26], [[7,7,org],[10,10,per]]),
    (dataset_events[305][25], [[3,3,per],[17,17,gpe]]),
    (dataset_events[305][24], [[6,7,per],[8,9,per],[17,17,gpe]]),
    (dataset_events[305][23], [[1,1,per],[12,12,gpe],[17,17,gpe]]),
    (dataset_events[305][22], []),
    (dataset_events[305][21], [[11,11,gpe],[23,23,gpe]]),
    (dataset_events[305][20], [[1,1,org],[4,4,per],[8,8,gpe],[11,11,per]]),
    (dataset_events[305][19], [[0,0,per],[3,4,per]]),
    (dataset_events[305][18], [[0,1,per]]),
    (dataset_events[305][17], [[7,7,org],[16,16,gpe],[26,26,per]]),
    (dataset_events[305][16], [[10,10,org],[13,13,per],[15,15,per],[18,18,gpe]]),
    (dataset_events[305][15], [[0,0,per],[3,3,per],[5,6,per],[12,12,per]]),
    (dataset_events[305][14], [[1,1,per],[4,4,per],[14,14,per]]),
    (dataset_events[305][13], [[14,14,gpe],[17,17,per]]),
    (dataset_events[305][12], []),
    (dataset_events[305][11], [[1,1,gpe]]),
    (dataset_events[305][10], []),
    (dataset_events[305][9], [[5,5,gpe],[8,8,per],[11,11,gpe]]),
    (dataset_events[305][8], [[5,5,per],[13,13,gpe]]),
    (dataset_events[305][7], [[3,3,per],[14,14,per],[26,26,per]]),
    (dataset_events[305][6], [[3,3,per],[5,5,per]]),
    (dataset_events[305][5], [[3,4,per],[9,9,gpe],[12,12,gpe],[15,15,per]]),
    (dataset_events[305][4], [[16,17,per],[26,29,per]]),
    (dataset_events[305][3], []),
    (dataset_events[305][2], [[21,23,org],[31,31,gpe],[34,35,gpe]]),
    (dataset_events[305][1], [[0,0,org]]),
    (dataset_events[305][0], [[0,0,org]]),
    (dataset_events[304][11], [[0,0,org],[7,7,per],[17,17,per],[28,30,org]]),
    (dataset_events[304][10], [[0,0,per]]),
    (dataset_events[304][9], [[0,0,per]]),
    (dataset_events[304][8], [[2,2,gpe],[24,24,per]]),
    (dataset_events[304][7], []),
    (dataset_events[304][6], [[31,31,org]]),
    (dataset_events[304][5], [[9,9,per],[22,22,per]]),
    (dataset_events[304][4], [[13,13,gpe]]),
    (dataset_events[304][3], [[0,1,org],[8,9,per],[10,11,per]]),
    (dataset_events[304][2], [[0,1,per],[4,4,org],[9,9,org]]),
    (dataset_events[304][1], [[0,0,org]]),
    (dataset_events[304][0], [[0,1,per],[2,3,per],[10,10,gpe],[12,12,gpe],[14,14,gpe]]),
    (dataset_events[303][10], []),
    (dataset_events[303][9], [[4,4,org],[6,6,org],[19,19,per],[20,21,per],[26,26,per]]),
    (dataset_events[303][8], [[0,0,org],[15,16,gpe]]),
    (dataset_events[303][7], [[2,2,gpe],[3,4,org],[10,10,gpe]]),
    (dataset_events[303][6], [[1,1,org],[4,4,per],[12,12,per],[14,15,per],[17,18,per]]),
    (dataset_events[303][5], [[3,6,org],[9,9,org]]),
    (dataset_events[303][4], [[2,3,org]]),
    (dataset_events[303][3], [[0,0,gpe]]),
    (dataset_events[303][2], [[0,0,org],[2,3,per],[8,8,gpe],[10,10,org],[13,13,org],[19,19,gpe],[35,35,per]]),
    (dataset_events[303][1], [[1,1,org],[7,7,fac],[9,9,gpe],[11,12,gpe],[14,14,gpe]]),
    (dataset_events[303][0], []),
    (dataset_events[302][20], [[3,4,per],[6,6,gpe],[8,10,per],[12,12,gpe],[15,16,per]]),
    (dataset_events[302][19], [[3,4,per]]),
    (dataset_events[302][18], [[1,1,org],[5,5,fac],[11,11,gpe],[28,30,veh]]),
    (dataset_events[302][17], [[1,1,org],[11,11,veh],[15,15,fac],[18,18,per],[32,32,org],[41,42,veh]]),
    (dataset_events[302][16], [[15,15,veh],[18,18,per]]),
    (dataset_events[302][15], [[10,10,org],[12,12,org],[14,14,per],[21,21,fac],[33,33,veh]]),
    (dataset_events[302][14], [[0,0,per],[13,14,gpe],[16,16,gpe],[31,31,gpe]]),
    (dataset_events[302][13], [[0,0,gpe],[1,1,veh],[6,6,gpe]]),
    (dataset_events[302][12], [[7,7,org],[10,13,org],[15,16,org],[21,21,org]]),
    (dataset_events[302][11], [[3,3,per],[6,6,org],[9,9,org],[15,15,per]]),
    (dataset_events[302][10], [[2,2,org],[6,6,org],[13,13,gpe]]),
    (dataset_events[302][9], [[7,8,per],[10,14,per],[16,16,per]]),
    (dataset_events[302][8], []),
    (dataset_events[302][7], [[3,3,per]]),
    (dataset_events[302][6], [[1,1,loc]]),
    (dataset_events[302][5], [[3,3,fac],[13,14,gpe],[16,16,gpe],[18,18,gpe]]),
    (dataset_events[302][4], [[1,1,gpe],[4,4,org],[9,9,gpe],[10,10,org],[20,20,veh],[26,26,per],[28,28,gpe],[37,37,veh]]),
    (dataset_events[302][3], [[1,1,org],[21,25,org],[27,27,org],[32,33,fac]]),
    (dataset_events[302][2], [[1,1,org],[3,3,org],[10,10,gpe],[22,22,org],[30,31,gpe],[34,34,gpe]]),
    (dataset_events[302][1], [[1,1,loc],[4,4,org],[17,17,veh],[21,21,fac],[23,23,gpe],[34,34,gpe],[37,38,org],[39,40,org],[48,48,per],[51,51,org]]),
    (dataset_events[302][0], [[0,0,gpe],[2,2,gpe],[7,7,org],[10,11,org],[15,17,veh],[19,19,gpe],[36,36,org],[41,41,loc],[52,52,gpe],[54,54,gpe]]),
    (dataset_events[301][0], [[0, 0,gpe], [2,2,org], [5,6,org], [7,7,org], [10,10,per],[18, 19,fac] ,[21,21,gpe],[29,29,per],[33,33,org], [45,45,gpe]]),
    (dataset_events[301][1], [[4,5,org], [16,19,fac], [26,27,loc], [29,29,gpe]]),
    (dataset_events[301][2], [[0,0,org]]),
    (dataset_events[301][3], [[0,1,per], [10,11,per], [12,13,per], [23,23,gpe], [24,24,org], [35,35,loc],[45,45,gpe],[47,47,gpe],[49,49,gpe]]),
    (dataset_events[301][4], [[0,0,per],[4,4, per],[9,9,per],[10,11,per],[15,15,gpe],[16,18,per],[26,26,per],[35,35,loc],[44,44,org]]),
    (dataset_events[301][5], [[0,0,per],[7,7,gpe],[9,12,gpe]]),
    (dataset_events[301][6], [[16,16,gpe],[18,18,org],[19,19,org]]),
    (dataset_events[301][7], [[20,20,gpe],[23,26,org]]),
    (dataset_events[301][8], [[1,1,per],[7,7,fac]]),
    (dataset_events[301][9], [[1,1,org]]),
    (dataset_events[301][10], [[1,1,per],[3,3,org]]),
    (dataset_events[301][11], [[1,1,per],[3,3,org],[10,10,gpe]]),
    (dataset_events[301][12], [[1,1,gpe],[9,9,org],[22,23,loc],[26,26,gpe],[31,32,org]]),
    (dataset_events[301][13], [[1,2,loc],[18,18,loc],[32,33,fac]]),
    (dataset_events[301][14], []),
    (dataset_events[301][15], [[1,1,gpe],[4,4,org],[14,17,fac],[20,20,fac]])]

# %% [markdown]
# #### Functions to add labels to dataset

# %%
#Generates NER object
def generate_NER(lst,sent):
    ret=[document.NER(ner=tup, sentence=sent, sentence_offsets=True) for tup in lst]
    return ret

#Adds list of NER objects for each sentence in the articles
def add_NER_from_dict(dicto):
    for idx,i in enumerate(dicto):
        sent=i[0]
        nerList=i[1]
        try:
            sent.ner=generate_NER(nerList, sent)
        except:
            print(idx)
            print(nerList)
            print("------")


add_NER_from_dict(dicto1)
add_NER_from_dict(dicto2)

# %%
#Extracts only articles with hand labelled NER tags
def get_labelled_docs(dataset):
    documents=[]
    for doc in dataset:
        for sent in doc:
            if sent.ner:
                documents.append(doc)
                break
    return documents
            
documents=get_labelled_docs(dataset_events)

# %%
#Error when the "ner" field in a sentence is undefined ==> define as empty list
def handle_empty_ner(documents):
    for idx_doc, doc in enumerate(documents):
        for idx_sent, sent in enumerate(doc):
            if not sent.ner:
                sent.ner=[]
handle_empty_ner(documents)

# %%
#Create dataset that only contains labelled articles using filtered documents, extracted from get_labelled_docs(dataset)

labelled_test=document.Dataset(documents)
labelled_test.to_jsonl("/Users/jdklee/Documents/StatisticalML/labelled_test_data_events.jsonl")
labelled_test
# Out:
# Dataset with 59 documents.

# %% [markdown]
# # Evaluate
#
# #### Please refer to readme.md for detailed instructions on evaluation

# %%
# !allennlp evaluate \
  /Users/jdklee/Downloads/ace05-event.tar.gz \
  /Users/jdklee/Documents/StatisticalML/labelled_test_data_events.jsonl \
  --include-package dygie \
  --cuda-device -1  \
# Out:
# 2021-03-12 03:17:21,334 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2021-03-12 03:17:21,358 - INFO - allennlp.models.archival - loading archive file /Users/jdklee/Downloads/ace05-event.tar.gz
# 2021-03-12 03:17:21,358 - INFO - allennlp.models.archival - extracting archive file /Users/jdklee/Downloads/ace05-event.tar.gz to temp dir /var/folders/rd/z8rz4jd560l87g1x091pr6kh0000gn/T/tmpd_bo1f59
# 2021-03-12 03:17:25,203 - INFO - allennlp.data.vocabulary - Loading token dictionary from /var/folders/rd/z8rz4jd560l87g1x091pr6kh0000gn/T/tmpd_bo1f59/vocabulary.
# 2021-03-12 03:17:25,378 - INFO - transformers.configuration_utils - loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/roberta-base-config.json from cache at /Users/jdklee/.cache/torch/transformers/e1a2a406b5a05063c31f4dfdee7608986ba7c6393f7f79db5e69dcd197208534.117c81977c5979de8c088352e74ec6e70f5c66096c28b61d3c50101609b39690
# ...
